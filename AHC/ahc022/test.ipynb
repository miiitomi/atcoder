# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./res.txt", sep=" ", header=None)
df
# Out:
#                  0   1        2         3
# 0     7.230610e+06   0  4000000   9730100
# 1     4.711890e+06   0  4000000  17122900
# 2     4.345900e+06   0  4000000  18910200
# 3     7.129620e+06   0  4000000   9926000
# 4     9.915520e+06   0  4000000   5985200
# ...            ...  ..      ...       ...
# 2995  1.583230e-01  83  4000000   1613800
# 2996  2.359260e-01  81  4000000   1891200
# 2997  5.194020e+01  57  4000000   1662700
# 2998  9.327990e-02  85  4000000   2106700
# 2999  7.722290e-03  96  4000000   2340100
#
# [3000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3000 non-null   float64
#  1   1       3000 non-null   int64
#  2   2       3000 non-null   int64
#  3   3       3000 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 93.9 KB

# %%
df["Total Score"] = df[0].astype(int) + 1
df
# Out:
#                  0   1        2         3  Total Score
# 0     7.230610e+06   0  4000000   9730100      7230611
# 1     4.711890e+06   0  4000000  17122900      4711891
# 2     4.345900e+06   0  4000000  18910200      4345901
# 3     7.129620e+06   0  4000000   9926000      7129621
# 4     9.915520e+06   0  4000000   5985200      9915521
# ...            ...  ..      ...       ...          ...
# 2995  1.583230e-01  83  4000000   1613800            1
# 2996  2.359260e-01  81  4000000   1891200            1
# 2997  5.194020e+01  57  4000000   1662700           52
# 2998  9.327990e-02  85  4000000   2106700            1
# 2999  7.722290e-03  96  4000000   2340100            1
#
# [3000 rows x 5 columns]

# %%
df["Num Worngs"] = df[1]

# %%
df
# Out:
#                  0   1        2         3  Total Score  Num Worngs
# 0     7.230610e+06   0  4000000   9730100      7230611           0
# 1     4.711890e+06   0  4000000  17122900      4711891           0
# 2     4.345900e+06   0  4000000  18910200      4345901           0
# 3     7.129620e+06   0  4000000   9926000      7129621           0
# 4     9.915520e+06   0  4000000   5985200      9915521           0
# ...            ...  ..      ...       ...          ...         ...
# 2995  1.583230e-01  83  4000000   1613800            1          83
# 2996  2.359260e-01  81  4000000   1891200            1          81
# 2997  5.194020e+01  57  4000000   1662700           52          57
# 2998  9.327990e-02  85  4000000   2106700            1          85
# 2999  7.722290e-03  96  4000000   2340100            1          96
#
# [3000 rows x 6 columns]

# %%
df["Place Cost"] = df[2]

# %%
df["Move cost"] = df[3]

# %%
df["S"] = 0
idx = 0

for s in range(1, 31):
    for i in range(100):
        df.loc[idx, "S"] = s
        idx += 1

df
# Out:
#                  0   1        2         3  Total Score  Num Worngs  \
# 0     7.230610e+06   0  4000000   9730100      7230611           0
# 1     4.711890e+06   0  4000000  17122900      4711891           0
# 2     4.345900e+06   0  4000000  18910200      4345901           0
# 3     7.129620e+06   0  4000000   9926000      7129621           0
# 4     9.915520e+06   0  4000000   5985200      9915521           0
# ...            ...  ..      ...       ...          ...         ...
# 2995  1.583230e-01  83  4000000   1613800            1          83
# 2996  2.359260e-01  81  4000000   1891200            1          81
# 2997  5.194020e+01  57  4000000   1662700           52          57
# 2998  9.327990e-02  85  4000000   2106700            1          85
# 2999  7.722290e-03  96  4000000   2340100            1          96
#
#       Place Cost  Move cost   S
# 0        4000000    9730100   1
# 1        4000000   17122900   1
# 2        4000000   18910200   1
# ...

# %%
sns.barplot(data=df[df["S"]>=22], x='S', y="Total Score")
# Out:
# <Axes: xlabel='S', ylabel='Total Score'>
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# ...

# %%
df.loc[df["S"]==30].describe()
# Out:
#        Total Score  Num Worngs  Place Cost     Move cost      S
# count   100.000000  100.000000       100.0  1.000000e+02  100.0
# mean      5.740000   78.580000   4000000.0  1.798470e+06   30.0
# std      10.195681   11.415195         0.0  5.561870e+05    0.0
# min       1.000000   57.000000   4000000.0  7.014000e+05   30.0
# 25%       1.000000   70.750000   4000000.0  1.412375e+06   30.0
# 50%       1.000000   80.000000   4000000.0  1.703800e+06   30.0
# 75%       3.250000   88.000000   4000000.0  2.152450e+06   30.0
# max      52.000000   99.000000   4000000.0  3.325300e+06   30.0

# %%
df.loc[df["S"]==15].describe()
# Out:
#         Total Score  Num Worngs  Place Cost     Move cost      S
# count  1.000000e+02  100.000000       100.0  1.000000e+02  100.0
# mean   6.155256e+06    0.350000   4000000.0  1.240100e+07   15.0
# std    1.967871e+06    0.833333         0.0  4.681346e+06    0.0
# min    1.728361e+06    0.000000   4000000.0  5.204400e+06   15.0
# 25%    4.648568e+06    0.000000   4000000.0  8.978600e+06   15.0
# 50%    6.132366e+06    0.000000   4000000.0  1.160725e+07   15.0
# 75%    7.556341e+06    0.000000   4000000.0  1.430155e+07   15.0
# max    1.074760e+07    4.000000   4000000.0  2.656460e+07   15.0

# %%
df.loc[df["S"]==20].describe()
# Out:
#          Total Score  Num Worngs  Place Cost     Move cost      S
# count     100.000000  100.000000       100.0  1.000000e+02  100.0
# mean     3977.720000   46.660000   4000000.0  1.045594e+07   20.0
# std     15114.681278   11.109392         0.0  4.119977e+06    0.0
# min         2.000000   20.000000   4000000.0  4.041900e+06   20.0
# 25%        27.500000   38.000000   4000000.0  7.029675e+06   20.0
# 50%       179.000000   48.000000   4000000.0  1.008715e+07   20.0
# 75%      1843.500000   55.000000   4000000.0  1.343528e+07   20.0
# max    136781.000000   68.000000   4000000.0  1.953200e+07   20.0

# %%
sns.histplot(df[df["S"]==30], x="Num Worngs")
# Out:
# <Axes: xlabel='Num Worngs', ylabel='Count'>
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# findfont: Font family 'IPAexGothic' not found.
# ...
