# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
from matplotlib import logging; logging.getLogger('matplotlib.font_manager').disabled = True

# %%
df = pd.read_csv("./res.txt",sep=" ")
df
# Out:
#          N   L    S   total_score  num_right  num_wrong  place_cost  move_cost
# 0       60  10    1  7.577480e+07         60          0       40000    1179700
# 1       60  10    1  6.460780e+07         60          0       40000    1407800
# 2       60  10    1  7.155120e+07         60          0       40000    1257600
# 3       60  10    1  4.122910e+07         58          2       40000    1412300
# 4       60  10    1  6.790710e+07         60          0       40000    1332600
# ...    ...  ..  ...           ...        ...        ...         ...        ...
# 26995  100  50  900  8.469580e-04          2         98     4000000   33480000
# 26996  100  50  900  1.066650e-03          3         97     4000000   33200000
# 26997  100  50  900  8.369360e-04          2         98     4000000   33930000
# 26998  100  50  900  8.501250e-04          2         98     4000000   33340000
# 26999  100  50  900  1.693880e-03          5         95     4000000   32600000
#
# ...

# %%
Ns = [60, 80, 100]
Ls = [10, 30, 50]
fig, axes = plt.subplots(3, 3, figsize=(40,40))

for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df.loc[(df["N"]==N)&(df["L"]==L)], x="S", y="total_score", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()

# %%
Ns = [60, 80, 100]
Ls = [10, 30, 50]
fig, axes = plt.subplots(3, 3, figsize=(40,40))

for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df.loc[(df["S"]<441)&(df["N"]==N)&(df["L"]==L)], x="S", y="num_wrong", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()

# %%
Ns = [60, 80, 100]
Ls = [10, 30, 50]
fig, axes = plt.subplots(3, 3, figsize=(40,40))

for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df.loc[(df["N"]==N)&(df["L"]==L)&(df["S"]<=64)], x="S", y="num_wrong", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()

# %%
df.groupby("S").max()
# Out:
#        N   L  total_score  num_right  num_wrong  place_cost  move_cost
# S
# 1    100  50   85193400.0        100          6       40000   10270500
# 4    100  50   80899600.0        100          6       40000   10637600
# 9    100  50   81519500.0        100          4       40000   10327800
# 16   100  50   78173900.0        100          8       90000   10993400
# 25   100  50   72526800.0        100          4      160000   10411800
# 36   100  50   73362200.0        100          6      250000   10748200
# 49   100  50   62976300.0        100          6      360000   10742600
# 64   100  50   55230300.0        100          8      640000   10888600
# 81   100  50   45398800.0        100          5      810000   12578300
# 100  100  50   40889800.0        100          6     1210000   11213200
# 121  100  50   33549200.0        100          6     1690000   12151400
# 144  100  50   26128100.0        100          6     2560000   11611800
# ...

# %%
df2 = pd.read_csv("./res2.txt",sep=" ")
df2
# Out:
#         N   L    S  total_score  num_right  num_wrong  place_cost  move_cost
# 0      60  10    1   75774800.0         60          0       40000    1179700
# 1      60  10    1   64607800.0         60          0       40000    1407800
# 2      60  10    1   71551200.0         60          0       40000    1257600
# 3      60  10    1   64420500.0         60          0       40000    1412300
# 4      60  10    1   67907100.0         60          0       40000    1332600
# ...   ...  ..  ...          ...        ...        ...         ...        ...
# 8995  100  50  100    7207530.0         98          2     1210000    7569600
# 8996  100  50  100    3926610.0         96          4     1210000    9121400
# 8997  100  50  100    9874590.0        100          0     1210000    8817000
# 8998  100  50  100    9698570.0        100          0     1210000    9000800
# 8999  100  50  100    9754190.0        100          0     1210000    8942000
#
# [9000 rows x 8 columns]

# %%
df2.groupby("S").max()
# Out:
#        N   L  total_score  num_right  num_wrong  place_cost  move_cost
# S
# 1    100  50   85193400.0        100          0       40000   10287000
# 4    100  50   80899600.0        100          0       40000   10637600
# 9    100  50   81519500.0        100          0       40000   10327800
# 16   100  50   78173900.0        100          2       90000   10993400
# 25   100  50   72526800.0        100          4      160000   10479800
# 36   100  50   73362200.0        100          6      250000   10748200
# 49   100  50   62976300.0        100          6      360000   10742600
# 64   100  50   55230300.0        100          8      640000   10888600
# 81   100  50   45398800.0        100          5      810000   12578300
# 100  100  50   40889800.0        100          6     1210000   11213200

# %%
Ns = [60, 80, 100]
Ls = [10, 30, 50]
fig, axes = plt.subplots(3, 3, figsize=(40,40))

for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df2.loc[(df2["N"]==N)&(df2["L"]==L)], x="S", y="total_score", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()

# %%
Ns = [60, 80, 100]
Ls = [10, 30, 50]
fig, axes = plt.subplots(3, 3, figsize=(40,40))

for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df.loc[(df["N"]==N)&(df["L"]==L)&(df["S"]<=100)], x="S", y="total_score", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()

# %%
df3 = pd.read_csv("./res3.txt",sep=" ")
df3

print(df3.groupby("S").max())

Ns = [60, 80, 100]
Ls = [10, 30, 50]
fig, axes = plt.subplots(3, 3, figsize=(40,40))

for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df3.loc[(df3["N"]==N)&(df3["L"]==L)&(df3["S"]<=100)], x="S", y="total_score", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()
# Out:
#        N   L  total_score  num_right  num_wrong  place_cost  move_cost
# S
# 1    100  50   79904100.0        100          0        1600   11408400
# 4    100  50   79371400.0        100          0       10000   11408400
# 9    100  50   77525400.0        100          0       40000   11408400
# 16   100  50   74632400.0        100          2       90000   11408400
# 25   100  50   70927000.0        100          4      160000   11408400
# 36   100  50   66671100.0        100          4      250000   11408400
# 49   100  50   61850600.0        100          4      360000   11507800
# 64   100  50   52720400.0        100          4      640000   11507800
# 81   100  50   48384000.0        100          4      810000   11460100
# 100  100  50   39858100.0        100          4     1210000   11489200
