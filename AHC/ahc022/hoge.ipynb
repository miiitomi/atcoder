# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
from matplotlib import logging; logging.getLogger('matplotlib.font_manager').disabled = True

# %%
Ns = [60, 80, 100]
Ls = [10, 30, 50]

df = pd.read_csv("./res.txt",sep=" ")
df
# Out:
#          N   L    S   total_score  num_right  num_wrong  place_cost  move_cost
# 0       60  10    1  6.758580e+07         60          0        1600    1378000
# 1       60  10    1  6.964270e+07         60          0        1600    1334300
# 2       60  10    1  6.394680e+07         60          0        1600    1462200
# 3       60  10    1  7.946600e+07         60          0        1600    1156800
# 4       60  10    1  6.824540e+07         60          0        1600    1363700
# ...    ...  ..  ...           ...        ...        ...         ...        ...
# 26995  100  50  900  1.087940e-03          3         97     4000000   32470000
# 26996  100  50  900  1.058420e-03          3         97     4000000   33490000
# 26997  100  50  900  1.055610e-03          3         97     4000000   33590000
# 26998  100  50  900  2.560190e-03          7         93     4000000   33840000
# 26999  100  50  900  1.359550e-03          4         96     4000000   32480000
#
# [27000 rows x 8 columns]

# %%
fig, axes = plt.subplots(3, 3, figsize=(40,40))
for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df.loc[(df["N"]==N)&(df["L"]==L)], x="S", y="total_score", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(40,40))
for i in range(3):
    for j in range(3):
        N = Ns[i]
        L = Ls[j]
        sns.barplot(data=df.loc[(df["N"]==N)&(df["L"]==L)&(200 < df["S"])], x="S", y="num_wrong", ax=axes[i][j])
        axes[i][j].set_title(f"N={N}, L={L}")

plt.show()
