# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from matplotlib import logging; logging.getLogger('matplotlib.font_manager').disabled = True

# %%
N = 80
L = 50
p = 1

N**2 * 100*(10 + (L/(p+1)))
# Out:
# 22400000.0

# %%
df["L"].unique()
# Out:
# array([ 60,  80, 100])

# %%
s = 9
sns.histplot(df.loc[
    (df["L"]==50) & (df["N"]==80) & (df["S"] == s*s)
], x="move_cost")
# Out:
# <Axes: xlabel='move_cost', ylabel='Count'>
